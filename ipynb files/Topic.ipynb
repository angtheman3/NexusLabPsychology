# %%
#Installing bertopic into the environment:

# !pip install bertopic --quiet

# %%
from bertopic import BERTopic

# %%
#Other general imports:

import pandas as pd 
import numpy as np
import sklearn 
import matplotlib.pyplot as plt

# %%
#Importing all the datasets:


#Addiction:
add19 = pd.read_csv("/Users/angadh/Desktop/Nexus/addiction_2019_features_tfidf_256.csv")
add_pre = pd.read_csv("/Users/angadh/Desktop/Nexus/addiction_pre_features_tfidf_256.csv")


#Adhd
adhd18 = pd.read_csv("/Users/angadh/Desktop/Nexus/adhd_2018_features_tfidf_256.csv")
adhd19 = pd.read_csv("/Users/angadh/Desktop/Nexus/adhd_2019_features_tfidf_256.csv")
adhd_pre = pd.read_csv("/Users/angadh/Desktop/Nexus/adhd_pre_features_tfidf_256.csv")

#Anxiety:
anxiety18 = pd.read_csv("/Users/angadh/Desktop/Nexus/anxiety_2018_features_tfidf_256.csv")
anxiety19 = pd.read_csv("/Users/angadh/Desktop/Nexus/anxiety_2019_features_tfidf_256.csv")
anxiety_pre= pd.read_csv("/Users/angadh/Desktop/Nexus/anxiety_pre_features_tfidf_256.csv")

#Autism:
autism18 = pd.read_csv("/Users/angadh/Desktop/Nexus/bipolarreddit_2018_features_tfidf_256.csv")
autism19 = pd.read_csv("/Users/angadh/Desktop/Nexus/bipolarreddit_2019_features_tfidf_256.csv")
autism_pre= pd.read_csv("/Users/angadh/Desktop/Nexus/autism_pre_features_tfidf_256.csv")

#Bipolar:

bipolar18 = pd.read_csv("/Users/angadh/Desktop/Nexus/autism_2018_features_tfidf_256.csv")
bipolar19 = pd.read_csv("/Users/angadh/Desktop/Nexus/autism_2019_features_tfidf_256.csv")
bipolar_pre= pd.read_csv("/Users/angadh/Desktop/Nexus/bipolarreddit_pre_features_tfidf_256.csv")

#BPD:

bpd18 = pd.read_csv("/Users/angadh/Desktop/Nexus/bpd_2018_features_tfidf_256.csv")
bpd19 = pd.read_csv("/Users/angadh/Desktop/Nexus/bpd_2019_features_tfidf_256.csv")
bpd_pre= pd.read_csv("/Users/angadh/Desktop/Nexus/bpd_pre_features_tfidf_256.csv")

#Depression:

bpd18 = pd.read_csv("/Users/angadh/Desktop/Nexus/bpd_2018_features_tfidf_256.csv")
bpd19 = pd.read_csv("/Users/angadh/Desktop/Nexus/bpd_2019_features_tfidf_256.csv")
bpd_pre= pd.read_csv("/Users/angadh/Desktop/Nexus/bpd_pre_features_tfidf_256.csv")

#Depression:

depression18 = pd.read_csv("/Users/angadh/Desktop/Nexus/depression_2018_features_tfidf_256 (2).csv")
depression19 = pd.read_csv("/Users/angadh/Desktop/Nexus/depression_2019_features_tfidf_256 (1).csv")
depression_pre= pd.read_csv("/Users/angadh/Desktop/Nexus/depression_pre_features_tfidf_256.csv")

#EDA:

eda19 = pd.read_csv("/Users/angadh/Desktop/Nexus/EDAnonymous_2019_features_tfidf_256.csv")
eda_pre = pd.read_csv("/Users/angadh/Desktop/Nexus/EDAnonymous_pre_features_tfidf_256.csv")

#Health anxiety:

health18 = pd.read_csv("/Users/angadh/Desktop/Nexus/healthanxiety_2018_features_tfidf_256.csv")
health19 = pd.read_csv("/Users/angadh/Desktop/Nexus/healthanxiety_2019_features_tfidf_256.csv")
health_pre= pd.read_csv("/Users/angadh/Desktop/Nexus/healthanxiety_pre_features_tfidf_256.csv")

#Lonely:

lonely18 = pd.read_csv("/Users/angadh/Desktop/Nexus/lonely_2018_features_tfidf_256.csv")
lonely19 = pd.read_csv("/Users/angadh/Desktop/Nexus/lonely_2019_features_tfidf_256.csv")
lonely_pre= pd.read_csv("/Users/angadh/Desktop/Nexus/lonely_pre_features_tfidf_256.csv")

#Mental health:

mh18 = pd.read_csv("/Users/angadh/Desktop/Nexus/mentalhealth_2018_features_tfidf_256.csv")
mh19 = pd.read_csv("/Users/angadh/Desktop/Nexus/mentalhealth_2019_features_tfidf_256.csv")
mh_pre= pd.read_csv("/Users/angadh/Desktop/Nexus/mentalhealth_pre_features_tfidf_256.csv")

#PTSD:

ptsd18 = pd.read_csv("/Users/angadh/Desktop/Nexus/ptsd_2018_features_tfidf_256.csv")
ptsd19 = pd.read_csv("/Users/angadh/Desktop/Nexus/ptsd_2019_features_tfidf_256.csv")
ptsd_pre= pd.read_csv("/Users/angadh/Desktop/Nexus/ptsd_pre_features_tfidf_256.csv")

#Schizo:

schizo18 = pd.read_csv("/Users/angadh/Desktop/Nexus/schizophrenia_2018_features_tfidf_256 (2).csv")
schizo19 = pd.read_csv("/Users/angadh/Desktop/Nexus/schizophrenia_2019_features_tfidf_256 (1).csv")
schizo_pre= pd.read_csv("/Users/angadh/Desktop/Nexus/schizophrenia_pre_features_tfidf_256.csv")

#Social Anxiety:

social18 = pd.read_csv("/Users/angadh/Desktop/Nexus/socialanxiety_2018_features_tfidf_256.csv")
social19 = pd.read_csv("/Users/angadh/Desktop/Nexus/socialanxiety_2019_features_tfidf_256.csv")
social_pre= pd.read_csv("/Users/angadh/Desktop/Nexus/socialanxiety_pre_features_tfidf_256.csv")

# %%
####### Now doing the topic modelling: ##############

# Defining a function to drop all columns except "post:
def keep_only_post_column(df):
    columns_to_drop = [col for col in df.columns if col != "post"]
    return df.drop(columns=columns_to_drop)

# %%
# Applying the function to each thing:


eda_19 = keep_only_post_column(eda19)
edapre = keep_only_post_column(eda_pre)

adhd_18 = keep_only_post_column(adhd18)
adhd_19 = keep_only_post_column(adhd19)
adhdpre = keep_only_post_column(adhd_pre)


anxiety_18 = keep_only_post_column(anxiety18)
anxiety_19 = keep_only_post_column(anxiety19)
anxietypre = keep_only_post_column(anxiety_pre)

bipolar_18 = keep_only_post_column(bipolar18)
bipolar_19 = keep_only_post_column(bipolar19)
bipolarpre = keep_only_post_column(bipolar_pre)

bpd_18 = keep_only_post_column(bpd18)
bpd_19 = keep_only_post_column(bpd19)
bpdpre = keep_only_post_column(bpd_pre)

depression_18 = keep_only_post_column(depression18)
depression_19 = keep_only_post_column(depression19)
depressionpre = keep_only_post_column(depression_pre)

ha_18 = keep_only_post_column(health18)
ha_19 = keep_only_post_column(health19)
hapre = keep_only_post_column(health_pre)

lonely_18 = keep_only_post_column(lonely18)
lonely_19 = keep_only_post_column(lonely19)
lonelypre = keep_only_post_column(lonely_pre)

mh_18 = keep_only_post_column(mh18)
mh_19 = keep_only_post_column(mh19)
mhpre = keep_only_post_column(mh_pre)

ptsd_18 = keep_only_post_column(ptsd18)
ptsd_19 = keep_only_post_column(ptsd19)
ptsdpre = keep_only_post_column(ptsd_pre)

schizo_18 = keep_only_post_column(schizo18)
schizo_19 = keep_only_post_column(schizo19)
shcizopre = keep_only_post_column(schizo_pre)

social_18 = keep_only_post_column(social18)
social_19 = keep_only_post_column(social19)
socialpre = keep_only_post_column(social_pre)

# %%
#Import:

from sklearn.feature_extraction.text import CountVectorizer

# %%
#Intialsing model:

vectorizer_model = CountVectorizer(ngram_range=(1, 2), stop_words="english")

model = BERTopic(
    vectorizer_model=vectorizer_model,
    language='english',
    calculate_probabilities=True,
    verbose=True
)

# %%
eda_texts = eda_19["post"]

# %%
#Restoring the posts colums as the texts:

eda_19 = eda_19["post"]
edapre = edapre["post"]

adhd_18 = adhd_18["post"]
adhd_19 = adhd_19["post"]
adhdpre = adhdpre["post"]


anxiety_18 = anxiety_18["post"]
anxiety_19 = anxiety_19["post"]
anxietypre = anxietypre["post"]

bipolar_18 = bipolar_18["post"]
bipolar_19 = bipolar_19["post"]
bipolarpre = bipolarpre["post"]

bpd_18 = bpd_18["post"]
bpd_19 = bpd_19["post"]
bpdpre = bpdpre["post"] 

depression_18 = depression_18["post"]
depression_19 = depression_19["post"]
depressionpre = depressionpre["post"]

ha_18 = ha_18["post"]
ha_19 = ha_19["post"]
hapre = hapre["post"]

lonely_18 = lonely_18["post"]
lonely_19 = lonely_19["post"]
lonelypre = lonelypre["post"] 

mh_18 = mh_18["post"]
mh_19 = mh_19["post"] 
mhpre = mhpre["post"]

ptsd_18 = ptsd_18["post"]
ptsd_19 = ptsd_19["post"] 
ptsdpre = ptsdpre["post"]

schizo_18 = schizo_18["post"]
schizo_19 = schizo_19["post"]
shcizopre = shcizopre["post"]

social_18 = social_18["post"]
social_19 = social_19["post"]
socialpre = socialpre["post"]

# %%
topics, probs = model.fit_transform(eda_19)
# Out:
# 2024-03-02 15:39:19,841 - BERTopic - Embedding - Transforming documents to embeddings.
